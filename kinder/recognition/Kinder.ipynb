# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset

import torchvision
import torchvision.datasets as tds
from torchvision import transforms
from torchvision import models

import os
import matplotlib.pyplot as plt
import numpy as np
import json
import urllib
from PIL import Image

# %%
# !unzip -q "drive/My Drive/data_recognition/train_data.zip"
train_folder = 'train_data/'
print('Number of files in the train folder', len(os.listdir(train_folder)))

# !unzip -q "drive/My Drive/data_recognition/test_data.zip"
test_folder = 'test_data/'
print('Number of files in the test folder', len(os.listdir(test_folder)))
# Out:
# replace train_data/chili-dog_7861.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# Number of files in the train folder 4870
# replace test_data/kinder_31.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# Number of files in the test folder 1210

# %%
device = torch.device("cuda:0")

# %%
from os import listdir
from os.path import isfile, join

class KinderDataset(Dataset):
  
  def __init__(self, folder, transform=None):
    self.folder = folder
    self.transform = transform
    self.file_names = sorted([f for f in listdir(self.folder) if isfile(join(self.folder, f)) and not f.startswith('.')])
  
  def __len__(self):
    return len(self.file_names)

  def __getitem__(self, index): 
    file_name = self.file_names[index]
    img_id = os.path.join(self.folder, file_name)
    y = 1 if file_name.startswith('kinder') else 0
    img = Image.open(img_id)
        
    if self.transform:
      img = self.transform(img)

    return img, y, img_id

# %%
def visualize_samples(dataset, indices, title=None, count=10):
    plt.figure(figsize=(count*3,3))
    display_indices = indices[:count]
    if title:
        plt.suptitle("%s %s/%s" % (title, len(display_indices), len(indices)))        
    for i, index in enumerate(display_indices):    
        x, y, _ = dataset[index]
        plt.subplot(1, count, i+1)
        plt.title("Label: %s" % y)
        plt.imshow(x)
        plt.grid(False)
        plt.axis('off')   
    
orig_dataset = KinderDataset(train_folder)
orig_test_dataset = KinderDataset(test_folder)
indices = np.random.choice(np.arange(len(orig_dataset)), 10, replace=False)

visualize_samples(orig_dataset, indices, "Samples")

# %%
tfs = transforms.Compose([
                          transforms.Resize((224, 224)),
                          transforms.RandomHorizontalFlip(),
                          transforms.RandomVerticalFlip(p=0.5),
                          transforms.RandomRotation(30),
                          #transforms.ColorJitter(brightness=(30, 60), contrast=(30, 60), saturation=(30, 60), hue=0.3),
                          transforms.ToTensor(),
                          transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                               std=[0.229, 0.224, 0.225])                         
                       ])

data_train = KinderDataset(train_folder, transform = tfs)

data_test = KinderDataset(test_folder, transform = tfs)

# %%
batch_size = 64

validation_size = .3

data_size = len(data_train)
split = int(np.floor(validation_size * data_size))
indices = list(range(data_size))
np.random.shuffle(indices)

train_indices, val_indices = indices[:split], indices[split:]

train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_indices)
val_sampler = torch.utils.data.sampler.SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, sampler=train_sampler)
val_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, sampler=val_sampler)

# %%
def train_model(model, train_loader, val_loader, loss, optimizer,  scheduler=None, num_epochs=20):
  train_loss_history = []
  train_history = []
  val_loss_histroy = []
  val_histroy = []

  for i_epoch in range(num_epochs):
    model.train()

    train_loss_sum = 0
    correct_samples = 0
    all_samples = 0

    for i_step, (x, y, _) in enumerate(train_loader):
      x_gpu = x.to(device)
      y_gpu = y.to(device)
      prediction = model(x_gpu)
      step_loss = loss(prediction, y_gpu)
      optimizer.zero_grad()
      step_loss.backward()
      optimizer.step()

      y_hat = torch.argmax(prediction, 1)
      correct_samples += float(torch.sum(y_hat == y_gpu))
      all_samples += y.shape[0]
      train_loss_sum += step_loss
    
    train_loss = train_loss_sum / i_step
    train_accuracy = correct_samples / all_samples
    val_loss, val_accuracy = compute_accuracy(model, val_loader, loss)
    if scheduler:
      scheduler.step(val_loss)

    train_loss_history.append(train_loss)
    val_loss_histroy.append(val_loss)
    train_history.append(train_accuracy)
    val_histroy.append(val_accuracy)

    print('Epoch num: %f, Train loss: %f, Val loss: %f, Train accuracy: %f, Validation accuracy: %f' % (i_epoch, train_loss, val_loss, train_accuracy, val_accuracy))
  
  return train_loss_history, val_loss, train_history, val_histroy

def compute_accuracy(model, loader, loss):
  model.eval()

  correct_samples = 0
  all_samples = 0
  loss_sum = 0

  for i_step, (x, y, _) in enumerate(loader):
    x_gpu = x.to(device)
    y_gpu = y.to(device)

    prediction = model(x_gpu)
    y_hat = torch.argmax(prediction, 1)

    loss_val = loss(prediction, y_gpu)
    loss_sum += float(loss_val)

    correct_samples += float(torch.sum(y_hat == y_gpu))
    all_samples += y.shape[0]
    
  avg_loss = loss_sum / i_step
  accuracy = correct_samples / all_samples

  return avg_loss, accuracy

# %%
def load_imagenet_classes():
    classes_json = urllib.request.urlopen('https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json').read()
    classes = json.loads(classes_json)
    return { int(k): v[-1] for k, v in classes.items()}

def visualize_imagenet_samples(dataset, orig_dataset, model, indices, classes, title=None, count=10):
    plt.figure(figsize=(count*3,3))
    display_indices = indices[:count]
    if title:
        plt.suptitle("%s %s/%s" % (title, len(display_indices), len(indices)))        
    for i, index in enumerate(display_indices):    
        x, y, _ = dataset[index]
        x_gpu = x.to(device)
        pred = model(torch.unsqueeze(x_gpu, 0))
        y_hat = torch.argmax(pred, 1)
        clas = classes[int(y_hat)]
        image, _, _ = orig_dataset[index]
        plt.subplot(1,count,i+1)
        plt.title("Label: %s" % clas)
        plt.imshow(image)
        plt.grid(False)
        plt.axis('off')

model = models.resnet18(pretrained=True)
model.type(torch.cuda.FloatTensor)
model.to(device)

model.eval()

classes = load_imagenet_classes()
indices = np.random.choice(np.arange(len(classes)), 10, replace=False)
visualize_imagenet_samples(data_train, orig_dataset, model, indices, classes)

# %%
model = models.resnet50(pretrained=True)
      
for param in model.parameters():
  param.requires_grad = False
        
old_fc = model.fc
model.fc = nn.Linear(old_fc.in_features, 2)
      
model.type(torch.cuda.FloatTensor)
model.to(device)
      
parameters = model.fc.parameters()
      
loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
optimizer = optim.Adam(parameters, lr=0.01, weight_decay=0.01)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=2)

# %%
train_loss_history, val_loss, train_history, val_histroy = train_model(model, train_loader, val_loader, loss, optimizer, scheduler, 10)
# Out:
# Epoch num: 0.000000, Train loss: 0.817607, Val loss: 0.134171, Train accuracy: 0.935616, Validation accuracy: 0.949545
# Epoch num: 1.000000, Train loss: 0.049091, Val loss: 0.084379, Train accuracy: 0.979452, Validation accuracy: 0.973893
# Epoch num: 2.000000, Train loss: 0.052528, Val loss: 0.047109, Train accuracy: 0.976027, Validation accuracy: 0.982400
# Epoch num: 3.000000, Train loss: 0.018712, Val loss: 0.035279, Train accuracy: 0.992466, Validation accuracy: 0.987680
# Epoch num: 4.000000, Train loss: 0.018636, Val loss: 0.038825, Train accuracy: 0.993836, Validation accuracy: 0.986506
# Epoch num: 5.000000, Train loss: 0.041837, Val loss: 0.057391, Train accuracy: 0.982877, Validation accuracy: 0.977999
# Epoch num: 6.000000, Train loss: 0.044360, Val loss: 0.059459, Train accuracy: 0.983562, Validation accuracy: 0.980639
# Epoch num: 7.000000, Train loss: 0.014142, Val loss: 0.032605, Train accuracy: 0.993836, Validation accuracy: 0.987973
# Epoch num: 8.000000, Train loss: 0.012403, Val loss: 0.033689, Train accuracy: 0.996575, Validation accuracy: 0.986800
# Epoch num: 9.000000, Train loss: 0.017065, Val loss: 0.031804, Train accuracy: 0.996575, Validation accuracy: 0.989146

# %%
def evaluate_model(model, loader):
  predictions = []
  gt = []
  for (x, y, _) in loader:
    x_gpu = x.to(device)
    y_gpu = y.to(device)

    prediction = model(x_gpu)
    y_hat = torch.argmax(prediction, 1)

    predictions.append(int(y_hat))
    gt.append(int(y))

  return np.asarray(predictions), np.asarray(gt)

# %%
def binary_classification_metrics(prediction, ground_truth):
    tp = np.sum((prediction == 1) & (ground_truth == 1))
    tn = np.sum((prediction == 0) & (ground_truth == 0))
    fp = np.sum((prediction == 1) & (ground_truth == 0))
    fn = np.sum((prediction == 0) & (ground_truth == 1))

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    f1 = 2 * precision * recall / (precision + recall)

    return precision, recall, f1, accuracy

# %%
test_loader = torch.utils.data.DataLoader(data_test)
prediction, gt = evaluate_model(model, test_loader)
precision, recall, f1, accuracy = binary_classification_metrics(prediction, gt)
print('Precision: %f, Recall: %f, F1: %f, Accuracy: %f' % (precision, recall, f1, accuracy))
# Out:
# Precision: 0.916667, Recall: 0.932203, F1: 0.924370, Accuracy: 0.992556

# %%
predictions, gt = evaluate_model(model, test_loader)

test_indices = np.array(range(len(data_test)))

false_positive = test_indices[np.nonzero((predictions == 1) & (gt == 0))]
visualize_samples(orig_test_dataset, false_positive, 'False positive')

false_negative = test_indices[np.nonzero((predictions == 0) & (gt == 1))]
visualize_samples(orig_test_dataset, false_negative, 'False negative')

# %%
test_loader = torch.utils.data.DataLoader(data_test)

learning_rates = [1e-2, 1e-3]
weight_decay = [1e-2, 1e-3, 1e-4]
schedulers = [(0.5, 2), (0.3, 3), (0.5, 5), (0.1, 2)]

for lr in learning_rates:
  for wd in weight_decay:
    for schdlr in schedulers:
      model = models.resnet18(pretrained=True)
      
      for param in model.parameters():
        param.requires_grad = False
        
      old_fc = model.fc
      model.fc = nn.Linear(old_fc.in_features, 2)
      
      model.type(torch.cuda.FloatTensor)
      model.to(device)
      
      parameters = model.fc.parameters()
      
      loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
      optimizer = optim.Adam(parameters, lr=lr, weight_decay=wd)
      scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=schdlr[0], patience=schdlr[1])

      train_loss_history, val_loss, train_history, val_histroy = train_model(model, train_loader, val_loader, loss, optimizer, scheduler, 10)

      prediction, gt = evaluate_model(model, test_loader)
      precision, recall, f1, accuracy = binary_classification_metrics(prediction, gt)
      print('Learning rate: %f, Weight decay: %f, Factor: %f, Patience: %f' % (lr, wd, schdlr[0], schdlr[1]))
      print('Precision: %f, Recall: %f, F1: %f, Accuracy: %f' % (precision, recall, f1, accuracy))
# Out:
# Epoch num: 0.000000, Train loss: 0.999207, Val loss: 0.441972, Train accuracy: 0.916147, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.152097, Val loss: 0.035127, Train accuracy: 0.953569, Validation accuracy: 0.986635
# Epoch num: 2.000000, Train loss: 0.052352, Val loss: 0.028198, Train accuracy: 0.979903, Validation accuracy: 0.991387
# Epoch num: 3.000000, Train loss: 0.024672, Val loss: 0.028000, Train accuracy: 0.991684, Validation accuracy: 0.991981
# Epoch num: 4.000000, Train loss: 0.020907, Val loss: 0.023893, Train accuracy: 0.994456, Validation accuracy: 0.991981
# Epoch num: 5.000000, Train loss: 0.020908, Val loss: 0.031375, Train accuracy: 0.995149, Validation accuracy: 0.985744
# Epoch num: 6.000000, Train loss: 0.015356, Val loss: 0.022861, Train accuracy: 0.996535, Validation accuracy: 0.992575
# Epoch num: 7.000000, Train loss: 0.013748, Val loss: 0.022535, Train accuracy: 0.997228, Validation accuracy: 0.993466
# Epoch num: 8.000000, Train loss: 0.013092, Val loss: 0.027283, Train accuracy: 0.998614, Validation accuracy: 0.988714
# Epoch num: 9.000000, Train loss: 0.017139, Val loss: 0.021833, Train accuracy: 0.995842, Validation accuracy: 0.991981
# Learning rate: 0.010000, Weight decay: 0.010000, Factor: 0.500000, Patience: 2.000000
# Precision: 0.924528, Recall: 0.830508, F1: 0.875000, Accuracy: 0.988420
# Epoch num: 0.000000, Train loss: 0.879414, Val loss: 0.339960, Train accuracy: 0.913375, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.115689, Val loss: 0.072283, Train accuracy: 0.966736, Validation accuracy: 0.978022
# Epoch num: 2.000000, Train loss: 0.041906, Val loss: 0.029479, Train accuracy: 0.986140, Validation accuracy: 0.991387
# Epoch num: 3.000000, Train loss: 0.029261, Val loss: 0.028827, Train accuracy: 0.988912, Validation accuracy: 0.987823
# Epoch num: 4.000000, Train loss: 0.028277, Val loss: 0.025639, Train accuracy: 0.990991, Validation accuracy: 0.990199
# Epoch num: 5.000000, Train loss: 0.015744, Val loss: 0.023633, Train accuracy: 0.996535, Validation accuracy: 0.992278
# Epoch num: 6.000000, Train loss: 0.015078, Val loss: 0.023236, Train accuracy: 0.998614, Validation accuracy: 0.994060
# Epoch num: 7.000000, Train loss: 0.013027, Val loss: 0.030697, Train accuracy: 0.997921, Validation accuracy: 0.987229
# Epoch num: 8.000000, Train loss: 0.015477, Val loss: 0.023939, Train accuracy: 0.995842, Validation accuracy: 0.989902
# Epoch num: 9.000000, Train loss: 0.013591, Val loss: 0.021944, Train accuracy: 0.997921, Validation accuracy: 0.993169
# Learning rate: 0.010000, Weight decay: 0.010000, Factor: 0.300000, Patience: 3.000000
# Precision: 0.881356, Recall: 0.881356, F1: 0.881356, Accuracy: 0.988420
# Epoch num: 0.000000, Train loss: 0.685081, Val loss: 0.176252, Train accuracy: 0.925156, Validation accuracy: 0.937036
# Epoch num: 1.000000, Train loss: 0.093582, Val loss: 0.060751, Train accuracy: 0.972280, Validation accuracy: 0.977725
# Epoch num: 2.000000, Train loss: 0.039774, Val loss: 0.029121, Train accuracy: 0.987526, Validation accuracy: 0.988417
# Epoch num: 3.000000, Train loss: 0.029067, Val loss: 0.033384, Train accuracy: 0.992377, Validation accuracy: 0.991090
# Epoch num: 4.000000, Train loss: 0.022121, Val loss: 0.028640, Train accuracy: 0.995149, Validation accuracy: 0.987526
# Epoch num: 5.000000, Train loss: 0.014284, Val loss: 0.031089, Train accuracy: 0.995842, Validation accuracy: 0.987229
# Epoch num: 6.000000, Train loss: 0.015803, Val loss: 0.026348, Train accuracy: 0.995842, Validation accuracy: 0.993763
# Epoch num: 7.000000, Train loss: 0.018390, Val loss: 0.022102, Train accuracy: 0.995149, Validation accuracy: 0.993169
# Epoch num: 8.000000, Train loss: 0.018456, Val loss: 0.033871, Train accuracy: 0.995842, Validation accuracy: 0.985744
# Epoch num: 9.000000, Train loss: 0.012864, Val loss: 0.021281, Train accuracy: 0.997228, Validation accuracy: 0.992575
# Learning rate: 0.010000, Weight decay: 0.010000, Factor: 0.500000, Patience: 5.000000
# Precision: 0.912281, Recall: 0.881356, F1: 0.896552, Accuracy: 0.990074
# Epoch num: 0.000000, Train loss: 0.393342, Val loss: 0.128088, Train accuracy: 0.950104, Validation accuracy: 0.959608
# Epoch num: 1.000000, Train loss: 0.043050, Val loss: 0.026623, Train accuracy: 0.989605, Validation accuracy: 0.993169
# Epoch num: 2.000000, Train loss: 0.025376, Val loss: 0.038144, Train accuracy: 0.992377, Validation accuracy: 0.983665
# Epoch num: 3.000000, Train loss: 0.020396, Val loss: 0.029642, Train accuracy: 0.994456, Validation accuracy: 0.988417
# Epoch num: 4.000000, Train loss: 0.015563, Val loss: 0.023148, Train accuracy: 0.993763, Validation accuracy: 0.993466
# Epoch num: 5.000000, Train loss: 0.013291, Val loss: 0.022785, Train accuracy: 0.998614, Validation accuracy: 0.992575
# Epoch num: 6.000000, Train loss: 0.011346, Val loss: 0.022273, Train accuracy: 0.997921, Validation accuracy: 0.993169
# Epoch num: 7.000000, Train loss: 0.009442, Val loss: 0.023523, Train accuracy: 0.998614, Validation accuracy: 0.991090
# Epoch num: 8.000000, Train loss: 0.010245, Val loss: 0.028144, Train accuracy: 0.999307, Validation accuracy: 0.989308
# Epoch num: 9.000000, Train loss: 0.015669, Val loss: 0.020196, Train accuracy: 0.996535, Validation accuracy: 0.993169
# Learning rate: 0.010000, Weight decay: 0.010000, Factor: 0.100000, Patience: 2.000000
# Precision: 0.928571, Recall: 0.881356, F1: 0.904348, Accuracy: 0.990902
# Epoch num: 0.000000, Train loss: 0.649126, Val loss: 0.396667, Train accuracy: 0.934858, Validation accuracy: 0.825067
# Epoch num: 1.000000, Train loss: 0.120956, Val loss: 0.028802, Train accuracy: 0.958420, Validation accuracy: 0.989011
# Epoch num: 2.000000, Train loss: 0.032863, Val loss: 0.023480, Train accuracy: 0.989605, Validation accuracy: 0.993169
# Epoch num: 3.000000, Train loss: 0.021645, Val loss: 0.027404, Train accuracy: 0.995842, Validation accuracy: 0.992575
# Epoch num: 4.000000, Train loss: 0.019242, Val loss: 0.024692, Train accuracy: 0.995842, Validation accuracy: 0.990199
# Epoch num: 5.000000, Train loss: 0.010346, Val loss: 0.026130, Train accuracy: 0.998614, Validation accuracy: 0.989011
# Epoch num: 6.000000, Train loss: 0.009051, Val loss: 0.020203, Train accuracy: 0.998614, Validation accuracy: 0.992872
# Epoch num: 7.000000, Train loss: 0.008110, Val loss: 0.020038, Train accuracy: 1.000000, Validation accuracy: 0.992575
# Epoch num: 8.000000, Train loss: 0.007829, Val loss: 0.020020, Train accuracy: 0.998614, Validation accuracy: 0.992278
# Epoch num: 9.000000, Train loss: 0.007708, Val loss: 0.019850, Train accuracy: 0.998614, Validation accuracy: 0.992575
# Learning rate: 0.010000, Weight decay: 0.001000, Factor: 0.500000, Patience: 2.000000
# Precision: 0.925926, Recall: 0.847458, F1: 0.884956, Accuracy: 0.989247
# Epoch num: 0.000000, Train loss: 0.543809, Val loss: 0.332797, Train accuracy: 0.950104, Validation accuracy: 0.861301
# Epoch num: 1.000000, Train loss: 0.140540, Val loss: 0.031573, Train accuracy: 0.962578, Validation accuracy: 0.990199
# Epoch num: 2.000000, Train loss: 0.032153, Val loss: 0.022686, Train accuracy: 0.988912, Validation accuracy: 0.992872
# Epoch num: 3.000000, Train loss: 0.015906, Val loss: 0.026494, Train accuracy: 0.995842, Validation accuracy: 0.991387
# Epoch num: 4.000000, Train loss: 0.017905, Val loss: 0.021626, Train accuracy: 0.996535, Validation accuracy: 0.993169
# Epoch num: 5.000000, Train loss: 0.014209, Val loss: 0.022069, Train accuracy: 0.995842, Validation accuracy: 0.991981
# Epoch num: 6.000000, Train loss: 0.017509, Val loss: 0.017635, Train accuracy: 0.993763, Validation accuracy: 0.994060
# Epoch num: 7.000000, Train loss: 0.016224, Val loss: 0.017755, Train accuracy: 0.995149, Validation accuracy: 0.993466
# Epoch num: 8.000000, Train loss: 0.006635, Val loss: 0.021138, Train accuracy: 0.998614, Validation accuracy: 0.991684
# Epoch num: 9.000000, Train loss: 0.006607, Val loss: 0.021059, Train accuracy: 1.000000, Validation accuracy: 0.991981
# Learning rate: 0.010000, Weight decay: 0.001000, Factor: 0.300000, Patience: 3.000000
# Precision: 0.941176, Recall: 0.813559, F1: 0.872727, Accuracy: 0.988420
# Epoch num: 0.000000, Train loss: 0.734441, Val loss: 0.117388, Train accuracy: 0.920305, Validation accuracy: 0.959311
# Epoch num: 1.000000, Train loss: 0.099299, Val loss: 0.092380, Train accuracy: 0.965350, Validation accuracy: 0.970003
# Epoch num: 2.000000, Train loss: 0.045030, Val loss: 0.030807, Train accuracy: 0.984061, Validation accuracy: 0.987823
# Epoch num: 3.000000, Train loss: 0.023592, Val loss: 0.024259, Train accuracy: 0.993763, Validation accuracy: 0.992872
# Epoch num: 4.000000, Train loss: 0.021514, Val loss: 0.022350, Train accuracy: 0.992377, Validation accuracy: 0.992872
# Epoch num: 5.000000, Train loss: 0.014795, Val loss: 0.027360, Train accuracy: 0.995842, Validation accuracy: 0.989308
# Epoch num: 6.000000, Train loss: 0.010769, Val loss: 0.020523, Train accuracy: 0.997921, Validation accuracy: 0.991090
# Epoch num: 7.000000, Train loss: 0.012842, Val loss: 0.019469, Train accuracy: 0.996535, Validation accuracy: 0.992575
# Epoch num: 8.000000, Train loss: 0.016260, Val loss: 0.036081, Train accuracy: 0.996535, Validation accuracy: 0.985150
# Epoch num: 9.000000, Train loss: 0.011963, Val loss: 0.017909, Train accuracy: 0.995149, Validation accuracy: 0.993169
# Learning rate: 0.010000, Weight decay: 0.001000, Factor: 0.500000, Patience: 5.000000
# Precision: 0.905660, Recall: 0.813559, F1: 0.857143, Accuracy: 0.986766
# Epoch num: 0.000000, Train loss: 0.306956, Val loss: 0.067271, Train accuracy: 0.966736, Validation accuracy: 0.980992
# Epoch num: 1.000000, Train loss: 0.049766, Val loss: 0.022761, Train accuracy: 0.982675, Validation accuracy: 0.991684
# Epoch num: 2.000000, Train loss: 0.019162, Val loss: 0.019569, Train accuracy: 0.991684, Validation accuracy: 0.994357
# Epoch num: 3.000000, Train loss: 0.011843, Val loss: 0.025226, Train accuracy: 0.997228, Validation accuracy: 0.989308
# Epoch num: 4.000000, Train loss: 0.010446, Val loss: 0.048039, Train accuracy: 0.996535, Validation accuracy: 0.983665
# Epoch num: 5.000000, Train loss: 0.012575, Val loss: 0.021343, Train accuracy: 0.996535, Validation accuracy: 0.991981
# Epoch num: 6.000000, Train loss: 0.005437, Val loss: 0.020221, Train accuracy: 1.000000, Validation accuracy: 0.992278
# Epoch num: 7.000000, Train loss: 0.004654, Val loss: 0.020393, Train accuracy: 1.000000, Validation accuracy: 0.992278
# Epoch num: 8.000000, Train loss: 0.005566, Val loss: 0.020218, Train accuracy: 1.000000, Validation accuracy: 0.992278
# Epoch num: 9.000000, Train loss: 0.004924, Val loss: 0.020250, Train accuracy: 0.999307, Validation accuracy: 0.992278
# Learning rate: 0.010000, Weight decay: 0.001000, Factor: 0.100000, Patience: 2.000000
# Precision: 0.910714, Recall: 0.864407, F1: 0.886957, Accuracy: 0.989247
# Epoch num: 0.000000, Train loss: 0.538994, Val loss: 0.087718, Train accuracy: 0.933472, Validation accuracy: 0.961687
# Epoch num: 1.000000, Train loss: 0.068285, Val loss: 0.033677, Train accuracy: 0.975745, Validation accuracy: 0.987526
# Epoch num: 2.000000, Train loss: 0.027772, Val loss: 0.032471, Train accuracy: 0.990991, Validation accuracy: 0.992278
# Epoch num: 3.000000, Train loss: 0.023327, Val loss: 0.024948, Train accuracy: 0.991684, Validation accuracy: 0.990793
# Epoch num: 4.000000, Train loss: 0.020541, Val loss: 0.022186, Train accuracy: 0.991684, Validation accuracy: 0.993169
# Epoch num: 5.000000, Train loss: 0.015883, Val loss: 0.024904, Train accuracy: 0.995842, Validation accuracy: 0.990199
# Epoch num: 6.000000, Train loss: 0.013039, Val loss: 0.023237, Train accuracy: 0.996535, Validation accuracy: 0.991387
# Epoch num: 7.000000, Train loss: 0.009868, Val loss: 0.021770, Train accuracy: 0.997921, Validation accuracy: 0.992575
# Epoch num: 8.000000, Train loss: 0.007967, Val loss: 0.022143, Train accuracy: 0.999307, Validation accuracy: 0.993169
# Epoch num: 9.000000, Train loss: 0.011290, Val loss: 0.019417, Train accuracy: 0.997228, Validation accuracy: 0.992575
# Learning rate: 0.010000, Weight decay: 0.000100, Factor: 0.500000, Patience: 2.000000
# Precision: 0.927273, Recall: 0.864407, F1: 0.894737, Accuracy: 0.990074
# Epoch num: 0.000000, Train loss: 0.993887, Val loss: 0.507547, Train accuracy: 0.916147, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.178461, Val loss: 0.099784, Train accuracy: 0.963964, Validation accuracy: 0.963469
# Epoch num: 2.000000, Train loss: 0.062615, Val loss: 0.028659, Train accuracy: 0.978517, Validation accuracy: 0.989902
# Epoch num: 3.000000, Train loss: 0.035203, Val loss: 0.025542, Train accuracy: 0.984754, Validation accuracy: 0.991684
# Epoch num: 4.000000, Train loss: 0.026585, Val loss: 0.023473, Train accuracy: 0.991684, Validation accuracy: 0.992872
# Epoch num: 5.000000, Train loss: 0.022306, Val loss: 0.029620, Train accuracy: 0.991684, Validation accuracy: 0.991090
# Epoch num: 6.000000, Train loss: 0.016692, Val loss: 0.021106, Train accuracy: 0.993763, Validation accuracy: 0.993466
# Epoch num: 7.000000, Train loss: 0.011793, Val loss: 0.020746, Train accuracy: 0.997228, Validation accuracy: 0.991684
# Epoch num: 8.000000, Train loss: 0.012500, Val loss: 0.019444, Train accuracy: 0.997228, Validation accuracy: 0.992278
# Epoch num: 9.000000, Train loss: 0.007922, Val loss: 0.019640, Train accuracy: 0.998614, Validation accuracy: 0.994060
# Learning rate: 0.010000, Weight decay: 0.000100, Factor: 0.300000, Patience: 3.000000
# Precision: 0.836066, Recall: 0.864407, F1: 0.850000, Accuracy: 0.985112
# Epoch num: 0.000000, Train loss: 0.732124, Val loss: 0.067730, Train accuracy: 0.927235, Validation accuracy: 0.974458
# Epoch num: 1.000000, Train loss: 0.163183, Val loss: 0.124599, Train accuracy: 0.952876, Validation accuracy: 0.954262
# Epoch num: 2.000000, Train loss: 0.059631, Val loss: 0.024904, Train accuracy: 0.980596, Validation accuracy: 0.993169
# Epoch num: 3.000000, Train loss: 0.025382, Val loss: 0.022214, Train accuracy: 0.988912, Validation accuracy: 0.991387
# Epoch num: 4.000000, Train loss: 0.016050, Val loss: 0.021054, Train accuracy: 0.995842, Validation accuracy: 0.992575
# Epoch num: 5.000000, Train loss: 0.014347, Val loss: 0.023723, Train accuracy: 0.997921, Validation accuracy: 0.991090
# Epoch num: 6.000000, Train loss: 0.011750, Val loss: 0.019462, Train accuracy: 0.996535, Validation accuracy: 0.993169
# Epoch num: 7.000000, Train loss: 0.008988, Val loss: 0.020597, Train accuracy: 0.998614, Validation accuracy: 0.992872
# Epoch num: 8.000000, Train loss: 0.007091, Val loss: 0.020081, Train accuracy: 1.000000, Validation accuracy: 0.992575
# Epoch num: 9.000000, Train loss: 0.007735, Val loss: 0.022564, Train accuracy: 0.999307, Validation accuracy: 0.991387
# Learning rate: 0.010000, Weight decay: 0.000100, Factor: 0.500000, Patience: 5.000000
# Precision: 0.940000, Recall: 0.796610, F1: 0.862385, Accuracy: 0.987593
# Epoch num: 0.000000, Train loss: 0.421513, Val loss: 0.112473, Train accuracy: 0.947332, Validation accuracy: 0.962875
# Epoch num: 1.000000, Train loss: 0.035215, Val loss: 0.027718, Train accuracy: 0.989605, Validation accuracy: 0.990793
# Epoch num: 2.000000, Train loss: 0.025802, Val loss: 0.024338, Train accuracy: 0.990991, Validation accuracy: 0.991981
# Epoch num: 3.000000, Train loss: 0.018632, Val loss: 0.021910, Train accuracy: 0.994456, Validation accuracy: 0.992872
# Epoch num: 4.000000, Train loss: 0.016318, Val loss: 0.046548, Train accuracy: 0.997228, Validation accuracy: 0.981586
# Epoch num: 5.000000, Train loss: 0.009200, Val loss: 0.021247, Train accuracy: 0.997921, Validation accuracy: 0.991090
# Epoch num: 6.000000, Train loss: 0.007675, Val loss: 0.018650, Train accuracy: 0.998614, Validation accuracy: 0.992872
# Epoch num: 7.000000, Train loss: 0.009858, Val loss: 0.024699, Train accuracy: 0.997228, Validation accuracy: 0.989902
# Epoch num: 8.000000, Train loss: 0.013336, Val loss: 0.017756, Train accuracy: 0.995149, Validation accuracy: 0.993763
# Epoch num: 9.000000, Train loss: 0.015535, Val loss: 0.018250, Train accuracy: 0.995842, Validation accuracy: 0.992278
# Learning rate: 0.010000, Weight decay: 0.000100, Factor: 0.100000, Patience: 2.000000
# Precision: 0.852459, Recall: 0.881356, F1: 0.866667, Accuracy: 0.986766
# Epoch num: 0.000000, Train loss: 0.358548, Val loss: 0.282411, Train accuracy: 0.878725, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.219879, Val loss: 0.171244, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.158051, Val loss: 0.144705, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 3.000000, Train loss: 0.127506, Val loss: 0.117787, Train accuracy: 0.957727, Validation accuracy: 0.957232
# Epoch num: 4.000000, Train loss: 0.103221, Val loss: 0.099037, Train accuracy: 0.961192, Validation accuracy: 0.960202
# Epoch num: 5.000000, Train loss: 0.086709, Val loss: 0.085096, Train accuracy: 0.963964, Validation accuracy: 0.967627
# Epoch num: 6.000000, Train loss: 0.072670, Val loss: 0.079023, Train accuracy: 0.975745, Validation accuracy: 0.964360
# Epoch num: 7.000000, Train loss: 0.067040, Val loss: 0.065896, Train accuracy: 0.976438, Validation accuracy: 0.976240
# Epoch num: 8.000000, Train loss: 0.059032, Val loss: 0.060537, Train accuracy: 0.981982, Validation accuracy: 0.978319
# Epoch num: 9.000000, Train loss: 0.052240, Val loss: 0.055025, Train accuracy: 0.984754, Validation accuracy: 0.978913
# Learning rate: 0.001000, Weight decay: 0.010000, Factor: 0.500000, Patience: 2.000000
# Precision: 0.970588, Recall: 0.559322, F1: 0.709677, Accuracy: 0.977667
# Epoch num: 0.000000, Train loss: 0.216215, Val loss: 0.157893, Train accuracy: 0.947332, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.130555, Val loss: 0.114741, Train accuracy: 0.958420, Validation accuracy: 0.957232
# Epoch num: 2.000000, Train loss: 0.100445, Val loss: 0.087216, Train accuracy: 0.966736, Validation accuracy: 0.966736
# Epoch num: 3.000000, Train loss: 0.075309, Val loss: 0.077743, Train accuracy: 0.974359, Validation accuracy: 0.965251
# Epoch num: 4.000000, Train loss: 0.061740, Val loss: 0.058725, Train accuracy: 0.981289, Validation accuracy: 0.978616
# Epoch num: 5.000000, Train loss: 0.051220, Val loss: 0.051749, Train accuracy: 0.984061, Validation accuracy: 0.983368
# Epoch num: 6.000000, Train loss: 0.046791, Val loss: 0.047583, Train accuracy: 0.986140, Validation accuracy: 0.986041
# Epoch num: 7.000000, Train loss: 0.040226, Val loss: 0.043335, Train accuracy: 0.988219, Validation accuracy: 0.986932
# Epoch num: 8.000000, Train loss: 0.039733, Val loss: 0.043696, Train accuracy: 0.990298, Validation accuracy: 0.982180
# Epoch num: 9.000000, Train loss: 0.031557, Val loss: 0.037276, Train accuracy: 0.992377, Validation accuracy: 0.988120
# Learning rate: 0.001000, Weight decay: 0.010000, Factor: 0.300000, Patience: 3.000000
# Precision: 0.936170, Recall: 0.745763, F1: 0.830189, Accuracy: 0.985112
# Epoch num: 0.000000, Train loss: 0.263731, Val loss: 0.199205, Train accuracy: 0.944560, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.163147, Val loss: 0.143390, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.120300, Val loss: 0.102074, Train accuracy: 0.960499, Validation accuracy: 0.958420
# Epoch num: 3.000000, Train loss: 0.088987, Val loss: 0.080418, Train accuracy: 0.966736, Validation accuracy: 0.970003
# Epoch num: 4.000000, Train loss: 0.069942, Val loss: 0.065924, Train accuracy: 0.975745, Validation accuracy: 0.976240
# Epoch num: 5.000000, Train loss: 0.064659, Val loss: 0.058515, Train accuracy: 0.982675, Validation accuracy: 0.976537
# Epoch num: 6.000000, Train loss: 0.051075, Val loss: 0.051107, Train accuracy: 0.984754, Validation accuracy: 0.981586
# Epoch num: 7.000000, Train loss: 0.042618, Val loss: 0.045808, Train accuracy: 0.990298, Validation accuracy: 0.985150
# Epoch num: 8.000000, Train loss: 0.040799, Val loss: 0.042543, Train accuracy: 0.987526, Validation accuracy: 0.987823
# Epoch num: 9.000000, Train loss: 0.036712, Val loss: 0.040387, Train accuracy: 0.988912, Validation accuracy: 0.986635
# Learning rate: 0.001000, Weight decay: 0.010000, Factor: 0.500000, Patience: 5.000000
# Precision: 0.955556, Recall: 0.728814, F1: 0.826923, Accuracy: 0.985112
# Epoch num: 0.000000, Train loss: 0.216733, Val loss: 0.162757, Train accuracy: 0.957034, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.136455, Val loss: 0.110569, Train accuracy: 0.957727, Validation accuracy: 0.957232
# Epoch num: 2.000000, Train loss: 0.094282, Val loss: 0.080682, Train accuracy: 0.965350, Validation accuracy: 0.971191
# Epoch num: 3.000000, Train loss: 0.070538, Val loss: 0.063442, Train accuracy: 0.979210, Validation accuracy: 0.978319
# Epoch num: 4.000000, Train loss: 0.056386, Val loss: 0.053629, Train accuracy: 0.982675, Validation accuracy: 0.983071
# Epoch num: 5.000000, Train loss: 0.046535, Val loss: 0.047199, Train accuracy: 0.987526, Validation accuracy: 0.985447
# Epoch num: 6.000000, Train loss: 0.041548, Val loss: 0.042595, Train accuracy: 0.988219, Validation accuracy: 0.988714
# Epoch num: 7.000000, Train loss: 0.037532, Val loss: 0.038907, Train accuracy: 0.990991, Validation accuracy: 0.986635
# Epoch num: 8.000000, Train loss: 0.036276, Val loss: 0.038712, Train accuracy: 0.990991, Validation accuracy: 0.985150
# Epoch num: 9.000000, Train loss: 0.031485, Val loss: 0.034419, Train accuracy: 0.993763, Validation accuracy: 0.987823
# Learning rate: 0.001000, Weight decay: 0.010000, Factor: 0.100000, Patience: 2.000000
# Precision: 0.933333, Recall: 0.711864, F1: 0.807692, Accuracy: 0.983457
# Epoch num: 0.000000, Train loss: 0.254993, Val loss: 0.183310, Train accuracy: 0.937630, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.154094, Val loss: 0.129070, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.114932, Val loss: 0.100710, Train accuracy: 0.958420, Validation accuracy: 0.963469
# Epoch num: 3.000000, Train loss: 0.091202, Val loss: 0.076672, Train accuracy: 0.965350, Validation accuracy: 0.971488
# Epoch num: 4.000000, Train loss: 0.068861, Val loss: 0.067661, Train accuracy: 0.976438, Validation accuracy: 0.968518
# Epoch num: 5.000000, Train loss: 0.061349, Val loss: 0.056308, Train accuracy: 0.979210, Validation accuracy: 0.978022
# Epoch num: 6.000000, Train loss: 0.048481, Val loss: 0.048279, Train accuracy: 0.986140, Validation accuracy: 0.985150
# Epoch num: 7.000000, Train loss: 0.045117, Val loss: 0.043989, Train accuracy: 0.987526, Validation accuracy: 0.984853
# Epoch num: 8.000000, Train loss: 0.040366, Val loss: 0.040153, Train accuracy: 0.990298, Validation accuracy: 0.987823
# Epoch num: 9.000000, Train loss: 0.038881, Val loss: 0.037451, Train accuracy: 0.990298, Validation accuracy: 0.988417
# Learning rate: 0.001000, Weight decay: 0.001000, Factor: 0.500000, Patience: 2.000000
# Precision: 0.954545, Recall: 0.711864, F1: 0.815534, Accuracy: 0.984285
# Epoch num: 0.000000, Train loss: 0.225885, Val loss: 0.164781, Train accuracy: 0.953569, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.146129, Val loss: 0.120016, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.098293, Val loss: 0.089796, Train accuracy: 0.963271, Validation accuracy: 0.960202
# Epoch num: 3.000000, Train loss: 0.073822, Val loss: 0.070508, Train accuracy: 0.969508, Validation accuracy: 0.971191
# Epoch num: 4.000000, Train loss: 0.057719, Val loss: 0.058426, Train accuracy: 0.984061, Validation accuracy: 0.979507
# Epoch num: 5.000000, Train loss: 0.046246, Val loss: 0.052225, Train accuracy: 0.988912, Validation accuracy: 0.977428
# Epoch num: 6.000000, Train loss: 0.043118, Val loss: 0.047776, Train accuracy: 0.989605, Validation accuracy: 0.980398
# Epoch num: 7.000000, Train loss: 0.035984, Val loss: 0.042615, Train accuracy: 0.993763, Validation accuracy: 0.984259
# Epoch num: 8.000000, Train loss: 0.033292, Val loss: 0.038016, Train accuracy: 0.992377, Validation accuracy: 0.987823
# Epoch num: 9.000000, Train loss: 0.031081, Val loss: 0.035725, Train accuracy: 0.993070, Validation accuracy: 0.988417
# Learning rate: 0.001000, Weight decay: 0.001000, Factor: 0.300000, Patience: 3.000000
# Precision: 0.918367, Recall: 0.762712, F1: 0.833333, Accuracy: 0.985112
# Epoch num: 0.000000, Train loss: 0.278837, Val loss: 0.229440, Train accuracy: 0.915454, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.177815, Val loss: 0.147232, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.127218, Val loss: 0.114441, Train accuracy: 0.957727, Validation accuracy: 0.957232
# Epoch num: 3.000000, Train loss: 0.099838, Val loss: 0.091075, Train accuracy: 0.961885, Validation accuracy: 0.962875
# Epoch num: 4.000000, Train loss: 0.079661, Val loss: 0.075869, Train accuracy: 0.968815, Validation accuracy: 0.970300
# Epoch num: 5.000000, Train loss: 0.066322, Val loss: 0.065129, Train accuracy: 0.975745, Validation accuracy: 0.975943
# Epoch num: 6.000000, Train loss: 0.057849, Val loss: 0.057596, Train accuracy: 0.980596, Validation accuracy: 0.978913
# Epoch num: 7.000000, Train loss: 0.051804, Val loss: 0.052813, Train accuracy: 0.984061, Validation accuracy: 0.982477
# Epoch num: 8.000000, Train loss: 0.044057, Val loss: 0.047777, Train accuracy: 0.987526, Validation accuracy: 0.985447
# Epoch num: 9.000000, Train loss: 0.041538, Val loss: 0.043640, Train accuracy: 0.988219, Validation accuracy: 0.986932
# Learning rate: 0.001000, Weight decay: 0.001000, Factor: 0.500000, Patience: 5.000000
# Precision: 0.975610, Recall: 0.677966, F1: 0.800000, Accuracy: 0.983457
# Epoch num: 0.000000, Train loss: 0.200099, Val loss: 0.140652, Train accuracy: 0.956341, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.122518, Val loss: 0.098228, Train accuracy: 0.959113, Validation accuracy: 0.961390
# Epoch num: 2.000000, Train loss: 0.087342, Val loss: 0.073107, Train accuracy: 0.965350, Validation accuracy: 0.969112
# Epoch num: 3.000000, Train loss: 0.066560, Val loss: 0.059625, Train accuracy: 0.975745, Validation accuracy: 0.979804
# Epoch num: 4.000000, Train loss: 0.054091, Val loss: 0.052106, Train accuracy: 0.982675, Validation accuracy: 0.986338
# Epoch num: 5.000000, Train loss: 0.048726, Val loss: 0.045301, Train accuracy: 0.986140, Validation accuracy: 0.983368
# Epoch num: 6.000000, Train loss: 0.043354, Val loss: 0.040523, Train accuracy: 0.986833, Validation accuracy: 0.986932
# Epoch num: 7.000000, Train loss: 0.038230, Val loss: 0.036829, Train accuracy: 0.990991, Validation accuracy: 0.987823
# Epoch num: 8.000000, Train loss: 0.032356, Val loss: 0.034907, Train accuracy: 0.993070, Validation accuracy: 0.986932
# Epoch num: 9.000000, Train loss: 0.029373, Val loss: 0.032281, Train accuracy: 0.991684, Validation accuracy: 0.989308
# Learning rate: 0.001000, Weight decay: 0.001000, Factor: 0.100000, Patience: 2.000000
# Precision: 0.955556, Recall: 0.728814, F1: 0.826923, Accuracy: 0.985112
# Epoch num: 0.000000, Train loss: 0.290298, Val loss: 0.194818, Train accuracy: 0.950797, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.170299, Val loss: 0.140468, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.123909, Val loss: 0.101739, Train accuracy: 0.958420, Validation accuracy: 0.960202
# Epoch num: 3.000000, Train loss: 0.091661, Val loss: 0.079586, Train accuracy: 0.964657, Validation accuracy: 0.970300
# Epoch num: 4.000000, Train loss: 0.069257, Val loss: 0.066533, Train accuracy: 0.973666, Validation accuracy: 0.980101
# Epoch num: 5.000000, Train loss: 0.061750, Val loss: 0.056733, Train accuracy: 0.979210, Validation accuracy: 0.982477
# Epoch num: 6.000000, Train loss: 0.048562, Val loss: 0.051480, Train accuracy: 0.987526, Validation accuracy: 0.979210
# Epoch num: 7.000000, Train loss: 0.043947, Val loss: 0.046429, Train accuracy: 0.987526, Validation accuracy: 0.988714
# Epoch num: 8.000000, Train loss: 0.039795, Val loss: 0.042342, Train accuracy: 0.990991, Validation accuracy: 0.985744
# Epoch num: 9.000000, Train loss: 0.035690, Val loss: 0.039206, Train accuracy: 0.993763, Validation accuracy: 0.987526
# Learning rate: 0.001000, Weight decay: 0.000100, Factor: 0.500000, Patience: 2.000000
# Precision: 0.931818, Recall: 0.694915, F1: 0.796117, Accuracy: 0.982630
# Epoch num: 0.000000, Train loss: 0.234862, Val loss: 0.196694, Train accuracy: 0.939709, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.144883, Val loss: 0.136190, Train accuracy: 0.958420, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.113284, Val loss: 0.101593, Train accuracy: 0.958420, Validation accuracy: 0.959311
# Epoch num: 3.000000, Train loss: 0.088792, Val loss: 0.087173, Train accuracy: 0.965350, Validation accuracy: 0.959905
# Epoch num: 4.000000, Train loss: 0.068646, Val loss: 0.066403, Train accuracy: 0.975745, Validation accuracy: 0.973567
# Epoch num: 5.000000, Train loss: 0.055854, Val loss: 0.058691, Train accuracy: 0.981982, Validation accuracy: 0.977131
# Epoch num: 6.000000, Train loss: 0.051640, Val loss: 0.060128, Train accuracy: 0.984754, Validation accuracy: 0.972379
# Epoch num: 7.000000, Train loss: 0.045917, Val loss: 0.046365, Train accuracy: 0.985447, Validation accuracy: 0.987823
# Epoch num: 8.000000, Train loss: 0.042076, Val loss: 0.044206, Train accuracy: 0.987526, Validation accuracy: 0.981289
# Epoch num: 9.000000, Train loss: 0.036279, Val loss: 0.042130, Train accuracy: 0.993070, Validation accuracy: 0.981883
# Learning rate: 0.001000, Weight decay: 0.000100, Factor: 0.300000, Patience: 3.000000
# Precision: 1.000000, Recall: 0.644068, F1: 0.783505, Accuracy: 0.982630
# Epoch num: 0.000000, Train loss: 0.236460, Val loss: 0.166164, Train accuracy: 0.948025, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.147765, Val loss: 0.113918, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.105495, Val loss: 0.092379, Train accuracy: 0.964657, Validation accuracy: 0.959014
# Epoch num: 3.000000, Train loss: 0.083707, Val loss: 0.071022, Train accuracy: 0.968815, Validation accuracy: 0.967627
# Epoch num: 4.000000, Train loss: 0.064883, Val loss: 0.058057, Train accuracy: 0.977824, Validation accuracy: 0.978616
# Epoch num: 5.000000, Train loss: 0.056762, Val loss: 0.053422, Train accuracy: 0.979903, Validation accuracy: 0.988120
# Epoch num: 6.000000, Train loss: 0.047934, Val loss: 0.045235, Train accuracy: 0.986140, Validation accuracy: 0.987526
# Epoch num: 7.000000, Train loss: 0.041014, Val loss: 0.041718, Train accuracy: 0.988912, Validation accuracy: 0.989011
# Epoch num: 8.000000, Train loss: 0.040702, Val loss: 0.038431, Train accuracy: 0.991684, Validation accuracy: 0.990199
# Epoch num: 9.000000, Train loss: 0.034436, Val loss: 0.037425, Train accuracy: 0.991684, Validation accuracy: 0.986041
# Learning rate: 0.001000, Weight decay: 0.000100, Factor: 0.500000, Patience: 5.000000
# Precision: 1.000000, Recall: 0.661017, F1: 0.795918, Accuracy: 0.983457
# Epoch num: 0.000000, Train loss: 0.283867, Val loss: 0.228521, Train accuracy: 0.923770, Validation accuracy: 0.956638
# Epoch num: 1.000000, Train loss: 0.177335, Val loss: 0.149257, Train accuracy: 0.957727, Validation accuracy: 0.956638
# Epoch num: 2.000000, Train loss: 0.135991, Val loss: 0.114488, Train accuracy: 0.957727, Validation accuracy: 0.959905
# Epoch num: 3.000000, Train loss: 0.098703, Val loss: 0.091694, Train accuracy: 0.959113, Validation accuracy: 0.965845
# Epoch num: 4.000000, Train loss: 0.079432, Val loss: 0.075984, Train accuracy: 0.966736, Validation accuracy: 0.971191
# Epoch num: 5.000000, Train loss: 0.067735, Val loss: 0.065179, Train accuracy: 0.977824, Validation accuracy: 0.976537
# Epoch num: 6.000000, Train loss: 0.059606, Val loss: 0.059484, Train accuracy: 0.982675, Validation accuracy: 0.975943
# Epoch num: 7.000000, Train loss: 0.049848, Val loss: 0.053013, Train accuracy: 0.988219, Validation accuracy: 0.984556
# Epoch num: 8.000000, Train loss: 0.045802, Val loss: 0.048486, Train accuracy: 0.986140, Validation accuracy: 0.984556
# Epoch num: 9.000000, Train loss: 0.042859, Val loss: 0.047479, Train accuracy: 0.990991, Validation accuracy: 0.981289
# Learning rate: 0.001000, Weight decay: 0.000100, Factor: 0.100000, Patience: 2.000000
# Precision: 0.944444, Recall: 0.576271, F1: 0.715789, Accuracy: 0.977667
